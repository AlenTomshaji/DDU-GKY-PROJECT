# %% [markdown]
# # import libraries

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Load dataset & head function

# %%
df=pd.read_excel('Employee Sample Data.xlsx')
#print(df)
df.head(5)
# Out:
#      EEID        Full Name                 Job Title Department  \
# 0  E02387      Emily Davis                Sr. Manger         IT
# 1  E04105    Theodore Dinh       Technical Architect         IT
# 2  E02572     Luna Sanders                  Director    Finance
# 3  E02832  Penelope Jordan  Computer Systems Manager         IT
# 4  E01639        Austin Vo               Sr. Analyst    Finance
#
#             Business Unit  Gender  Ethnicity  Age  Hire Date  Annual Salary  \
# 0  Research & Development  Female      Black   55 2016-04-08         141604
# 1           Manufacturing    Male      Asian   59 1997-11-29          99975
# 2     Speciality Products  Female  Caucasian   50 2006-10-26         163099
# 3           Manufacturing  Female  Caucasian   26 2019-09-27          84913
# 4           Manufacturing    Male      Asian   55 1995-11-20          95409
#
#    Bonus %        Country       City  Exit Date
# 0     0.15  United States    Seattle 2021-10-16
# ...

# %% [markdown]
# # CUT

# %%
df.Age.unique()
# Out:
# array([55, 59, 50, 26, 57, 27, 25, 29, 34, 36, 51, 31, 41, 65, 64, 45, 56,
#        37, 44, 43, 63, 28, 61, 30, 32, 35, 53, 52, 40, 33, 46, 38, 58, 60,
#        42, 48, 54, 49, 39, 62, 47], dtype=int64)

# %%
df['age_group']=pd.cut(df.Age,bins=3,labels=('Young','Middle','senior'))
df
# Out:
#        EEID        Full Name                 Job Title  Department  \
# 0    E02387      Emily Davis                Sr. Manger          IT
# 1    E04105    Theodore Dinh       Technical Architect          IT
# 2    E02572     Luna Sanders                  Director     Finance
# 3    E02832  Penelope Jordan  Computer Systems Manager          IT
# 4    E01639        Austin Vo               Sr. Analyst     Finance
# ..      ...              ...                       ...         ...
# 995  E03094     Wesley Young               Sr. Analyst   Marketing
# 996  E01909     Lillian Khan                   Analyst     Finance
# 997  E04398      Oliver Yang                  Director   Marketing
# 998  E02521      Lily Nguyen               Sr. Analyst     Finance
# 999  E03545      Sofia Cheng            Vice President  Accounting
#
#               Business Unit  Gender  Ethnicity  Age  Hire Date  Annual Salary  \
# 0    Research & Development  Female      Black   55 2016-04-08         141604
# ...

# %%
age_cat=df.groupby(['Job Title'])['age_group']
age_cat.value_counts()
# Out:
# Job Title
# Account Representative  Young      9
#                         Middle     7
#                         senior     5
# Analyst                 Young     20
#                         senior    19
#                                   ..
# Test Engineer           Middle     4
#                         Young      3
# Vice President          Young     39
#                         Middle    37
#                         senior    29
# Name: age_group, Length: 99, dtype: int64

# %% [markdown]
# # Tail function

# %%
df.tail(5)
# Out:
#        EEID     Full Name       Job Title  Department        Business Unit  \
# 995  E03094  Wesley Young     Sr. Analyst   Marketing  Speciality Products
# 996  E01909  Lillian Khan         Analyst     Finance  Speciality Products
# 997  E04398   Oliver Yang        Director   Marketing  Speciality Products
# 998  E02521   Lily Nguyen     Sr. Analyst     Finance  Speciality Products
# 999  E03545   Sofia Cheng  Vice President  Accounting            Corporate
#
#      Gender  Ethnicity  Age  Hire Date  Annual Salary  Bonus %        Country  \
# 995    Male  Caucasian   33 2016-09-18          98427     0.00  United States
# 996  Female      Asian   44 2010-05-31          47387     0.00          China
# 997    Male      Asian   31 2019-06-10         176710     0.15  United States
# 998  Female      Asian   33 2012-01-28          95960     0.00          China
# 999  Female      Asian   63 2020-07-26         216195     0.31  United States
#
#          City  Exit Date
# ...

# %% [markdown]
# # Sample function - randomly select data

# %%
df.sample(10)
# Out:
#        EEID        Full Name             Job Title       Department  \
# 196  E03520       Nolan Pena               Analyst        Marketing
# 133  E03849      Evelyn Jung               Analyst            Sales
# 649  E04940  Hudson Williams        Vice President            Sales
# 828  E00465     Brooklyn Cho   Technical Architect               IT
# 417  E03277      Caroline Hu            Sr. Manger        Marketing
# 992  E03058    Robert Wright   Technical Architect               IT
# 86   E01234       Jack Cheng              Director  Human Resources
# 930  E04089   Sebastian Fong            Sr. Manger               IT
# 439  E02730        Axel Soto      Quality Engineer      Engineering
# 565  E04799     Mila Roberts  Sr. Business Partner  Human Resources
#
#               Business Unit  Gender  Ethnicity  Age  Hire Date  Annual Salary  \
# 196           Manufacturing    Male     Latino   30 2018-06-21          56154
# ...

# %%
df.shape
# Out:
# (1000, 14)

# %%
df.columns
# Out:
# Index(['EEID', 'Full Name', 'Job Title', 'Department', 'Business Unit',
#        'Gender', 'Ethnicity', 'Age', 'Hire Date', 'Annual Salary', 'Bonus %',
#        'Country', 'City', 'Exit Date'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   EEID           1000 non-null   object
#  1   Full Name      1000 non-null   object
#  2   Job Title      1000 non-null   object
#  3   Department     1000 non-null   object
#  4   Business Unit  1000 non-null   object
#  5   Gender         1000 non-null   object
#  6   Ethnicity      1000 non-null   object
#  7   Age            1000 non-null   int64
#  8   Hire Date      1000 non-null   datetime64[ns]
#  9   Annual Salary  1000 non-null   int64
#  10  Bonus %        1000 non-null   float64
#  11  Country        1000 non-null   object
#  12  City           1000 non-null   object
#  13  Exit Date      85 non-null     datetime64[ns]
# dtypes: datetime64[ns](2), float64(1), int64(2), object(9)
# memory usage: 109.5+ KB

# %%
df.describe()
# Out:
#                Age  Annual Salary      Bonus %
# count  1000.000000    1000.000000  1000.000000
# mean     44.382000  113217.365000     0.088660
# std      11.246981   53545.985644     0.117856
# min      25.000000   40063.000000     0.000000
# 25%      35.000000   71430.250000     0.000000
# 50%      45.000000   96557.000000     0.000000
# 75%      54.000000  150782.250000     0.150000
# max      65.000000  258498.000000     0.400000

# %%
df.isnull().sum()
# Out:
# EEID               0
# Full Name          0
# Job Title          0
# Department         0
# Business Unit      0
# Gender             0
# Ethnicity          0
# Age                0
# Hire Date          0
# Annual Salary      0
# Bonus %            0
# Country            0
# City               0
# Exit Date        915
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.loc[500:505]
# Out:
#        EEID         Full Name              Job Title       Department  \
# 500  E02960         Nova Hill            Sr. Analyst       Accounting
# 501  E00096       Peyton Cruz   Development Engineer      Engineering
# 502  E02140        Naomi Zhao         Vice President  Human Resources
# 503  E00826         Rylee Bui                Analyst       Accounting
# 504  E03881       Andrew Reed  System Administrator                IT
# 505  E02604  Brooklyn Collins             Sr. Manger          Finance
#
#            Business Unit  Gender  Ethnicity  Age  Hire Date  Annual Salary  \
# 500        Manufacturing  Female  Caucasian   56 2018-03-10          90040
# 501        Manufacturing  Female     Latino   30 2016-05-26          91134
# 502  Speciality Products  Female      Asian   45 2021-09-22         201396
# 503            Corporate  Female      Asian   55 2011-12-22          54733
# 504            Corporate    Male      Black   28 2019-06-17          65341
# ...

# %%
df.Country.value_counts()
# Out:
# United States    643
# China            218
# Brazil           139
# Name: Country, dtype: int64

# %%
df.Gender.value_counts()
# Out:
# Female    518
# Male      482
# Name: Gender, dtype: int64

# %%
df.sort_values(by=['Department'], ascending=False)
# Out:
#        EEID         Full Name                   Job Title  Department  \
# 913  E00943     Elena Mendoza                    Director       Sales
# 508  E01760   Madeline Acosta  Sr. Account Representative       Sales
# 564  E01052       Parker Vang                     Analyst       Sales
# 561  E01488  Penelope Griffin                    Director       Sales
# 133  E03849       Evelyn Jung                     Analyst       Sales
# ..      ...               ...                         ...         ...
# 628  E02781         Athena Vu                    Director  Accounting
# 636  E02881    Leilani Sharma                 Sr. Analyst  Accounting
# 637  E03750        Jordan Cho                  Analyst II  Accounting
# 643  E01123    Madison Nelson                    Director  Accounting
# 999  E03545       Sofia Cheng              Vice President  Accounting
#
#               Business Unit  Gender  Ethnicity  Age  Hire Date  Annual Salary  \
# ...

# %%
df.assign(Departmentsales=df['Department']=="Sales")
# Out:
#        EEID        Full Name                 Job Title  Department  \
# 0    E02387      Emily Davis                Sr. Manger          IT
# 1    E04105    Theodore Dinh       Technical Architect          IT
# 2    E02572     Luna Sanders                  Director     Finance
# 3    E02832  Penelope Jordan  Computer Systems Manager          IT
# 4    E01639        Austin Vo               Sr. Analyst     Finance
# ..      ...              ...                       ...         ...
# 995  E03094     Wesley Young               Sr. Analyst   Marketing
# 996  E01909     Lillian Khan                   Analyst     Finance
# 997  E04398      Oliver Yang                  Director   Marketing
# 998  E02521      Lily Nguyen               Sr. Analyst     Finance
# 999  E03545      Sofia Cheng            Vice President  Accounting
#
#               Business Unit  Gender  Ethnicity  Age  Hire Date  Annual Salary  \
# 0    Research & Development  Female      Black   55 2016-04-08         141604
# ...

# %%
df.query('Department=="Sales"')
# Out:
#        EEID         Full Name               Job Title Department  \
# 5    E00644      Joshua Gupta  Account Representative      Sales
# 19   E04625         Adam Dang                Director      Sales
# 21   E04732        Eva Rivera                Director      Sales
# 23   E00671    Leonardo Dixon                 Analyst      Sales
# 24   E02071         Mateo Her          Vice President      Sales
# ..      ...               ...                     ...        ...
# 952  E03000       Hailey Hong  Account Representative      Sales
# 961  E03278     Nicholas Wong                Director      Sales
# 984  E02191         Maria Sun                Director      Sales
# 988  E00005  Riley Washington                Director      Sales
# 989  E04354      Raelynn Rios          Vice President      Sales
#
#               Business Unit  Gender  Ethnicity  Age  Hire Date  Annual Salary  \
# 5                 Corporate    Male      Asian   57 2017-01-24          50994
# ...

# %%
df1=df.dropna(subset=['Exit Date'])
df1.head()
# Out:
#       EEID        Full Name             Job Title       Department  \
# 0   E02387      Emily Davis            Sr. Manger               IT
# 7   E04332      Luke Martin               Analyst          Finance
# 14  E03496      Robert Yang           Sr. Analyst       Accounting
# 40  E01754         Owen Lam  Sr. Business Partner  Human Resources
# 61  E00502  Natalia Salazar           Sr. Analyst       Accounting
#
#              Business Unit  Gender Ethnicity  Age  Hire Date  Annual Salary  \
# 0   Research & Development  Female     Black   55 2016-04-08         141604
# 7            Manufacturing    Male     Black   25 2020-05-16          41336
# 14     Speciality Products    Male     Asian   31 2017-11-04          97078
# 40     Speciality Products    Male     Asian   30 2017-05-29          86317
# 61           Manufacturing  Female    Latino   44 2019-01-02          74691
#
#     Bonus %        Country     City  Exit Date
# 0      0.15  United States  Seattle 2021-10-16
# ...

# %%
df2=df.drop(columns=['Bonus %'])
df2.head(25)
# Out:
#       EEID        Full Name                 Job Title       Department  \
# 0   E02387      Emily Davis                Sr. Manger               IT
# 1   E04105    Theodore Dinh       Technical Architect               IT
# 2   E02572     Luna Sanders                  Director          Finance
# 3   E02832  Penelope Jordan  Computer Systems Manager               IT
# 4   E01639        Austin Vo               Sr. Analyst          Finance
# 5   E00644     Joshua Gupta    Account Representative            Sales
# 6   E01550      Ruby Barnes                   Manager               IT
# 7   E04332      Luke Martin                   Analyst          Finance
# 8   E04533    Easton Bailey                   Manager       Accounting
# 9   E03838  Madeline Walker               Sr. Analyst          Finance
# 10  E00591     Savannah Ali                Sr. Manger  Human Resources
# 11  E03344    Camila Rogers         Controls Engineer      Engineering
# ...

# %%
df.query('City=="Seattle"  & Age==55 & Department=="IT"')
#df.info()
# Out:
#      EEID    Full Name   Job Title Department           Business Unit  Gender  \
# 0  E02387  Emily Davis  Sr. Manger         IT  Research & Development  Female
#
#   Ethnicity  Age  Hire Date  Annual Salary  Bonus %        Country     City  \
# 0     Black   55 2016-04-08         141604     0.15  United States  Seattle
#
#    Exit Date
# 0 2021-10-16

# %%
df3=df.rename(columns={"Business Unit":"Business_Unit"})

# %%
df3.query('City=="Seattle"  & Age==55 & Business_Unit=="Research & Development"')
# Out:
#      EEID    Full Name   Job Title Department           Business_Unit  Gender  \
# 0  E02387  Emily Davis  Sr. Manger         IT  Research & Development  Female
#
#   Ethnicity  Age  Hire Date  Annual Salary  Bonus %        Country     City  \
# 0     Black   55 2016-04-08         141604     0.15  United States  Seattle
#
#    Exit Date
# 0 2021-10-16

# %% [markdown]
# # PIVOT

# %%
pivot=pd.pivot_table(values='Annual Salary',columns='City',data=df,aggfunc='median')
pivot.T
# Out:
#                 Annual Salary
# City
# Austin                97339.0
# Beijing               94735.0
# Chengdu               96164.5
# Chicago               95303.5
# Chongqing             94790.0
# Columbus              96757.0
# Manaus                95619.0
# Miami                 97865.0
# Phoenix               95670.0
# Rio de Janerio        97394.5
# Sao Paulo             95499.0
# Seattle               92175.5
# Shanghai             117062.5
