# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import klib as k
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor,AdaBoostRegressor, \
GradientBoostingRegressor, BaggingRegressor, ExtraTreesRegressor, HistGradientBoostingRegressor
from sklearn.svm import LinearSVR
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('possum.csv')
df
# Out:
#      case  site    Pop sex  age  hdlngth  skullw  totlngth  taill  footlgth  \
# 0       1     1    Vic   m  8.0     94.1    60.4      89.0   36.0      74.5
# 1       2     1    Vic   f  6.0     92.5    57.6      91.5   36.5      72.5
# 2       3     1    Vic   f  6.0     94.0    60.0      95.5   39.0      75.4
# 3       4     1    Vic   f  6.0     93.2    57.1      92.0   38.0      76.1
# 4       5     1    Vic   f  2.0     91.5    56.3      85.5   36.0      71.0
# ..    ...   ...    ...  ..  ...      ...     ...       ...    ...       ...
# 99    100     7  other   m  1.0     89.5    56.0      81.5   36.5      66.0
# 100   101     7  other   m  1.0     88.6    54.7      82.5   39.0      64.4
# 101   102     7  other   f  6.0     92.4    55.0      89.0   38.0      63.5
# 102   103     7  other   m  4.0     91.5    55.2      82.5   36.5      62.9
# 103   104     7  other   f  3.0     93.6    59.9      89.0   40.0      67.6
#
#      earconch   eye  chest  belly
# 0        54.5  15.2   28.0   36.0
# 1        51.2  16.0   28.5   33.0
# 2        51.9  15.5   30.0   34.0
# 3        52.2  15.2   28.0   34.0
# 4        53.2  15.1   28.5   33.0
# ..        ...   ...    ...    ...
# 99       46.8  14.8   23.0   27.0
# 100      48.0  14.0   25.0   33.0
# 101      45.4  13.0   25.0   30.0
# 102      45.9  15.4   25.0   29.0
# 103      46.0  14.8   28.5   33.5
#
# [104 rows x 14 columns]

# %%
df.head()
# Out:
#    case  site  Pop sex  age  hdlngth  skullw  totlngth  taill  footlgth  \
# 0     1     1  Vic   m  8.0     94.1    60.4      89.0   36.0      74.5
# 1     2     1  Vic   f  6.0     92.5    57.6      91.5   36.5      72.5
# 2     3     1  Vic   f  6.0     94.0    60.0      95.5   39.0      75.4
# 3     4     1  Vic   f  6.0     93.2    57.1      92.0   38.0      76.1
# 4     5     1  Vic   f  2.0     91.5    56.3      85.5   36.0      71.0
#
#    earconch   eye  chest  belly
# 0      54.5  15.2   28.0   36.0
# 1      51.2  16.0   28.5   33.0
# 2      51.9  15.5   30.0   34.0
# 3      52.2  15.2   28.0   34.0
# 4      53.2  15.1   28.5   33.0

# %%
df.tail()
# Out:
#      case  site    Pop sex  age  hdlngth  skullw  totlngth  taill  footlgth  \
# 99    100     7  other   m  1.0     89.5    56.0      81.5   36.5      66.0
# 100   101     7  other   m  1.0     88.6    54.7      82.5   39.0      64.4
# 101   102     7  other   f  6.0     92.4    55.0      89.0   38.0      63.5
# 102   103     7  other   m  4.0     91.5    55.2      82.5   36.5      62.9
# 103   104     7  other   f  3.0     93.6    59.9      89.0   40.0      67.6
#
#      earconch   eye  chest  belly
# 99       46.8  14.8   23.0   27.0
# 100      48.0  14.0   25.0   33.0
# 101      45.4  13.0   25.0   30.0
# 102      45.9  15.4   25.0   29.0
# 103      46.0  14.8   28.5   33.5

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 104 entries, 0 to 103
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   case      104 non-null    int64
#  1   site      104 non-null    int64
#  2   Pop       104 non-null    object
#  3   sex       104 non-null    object
#  4   age       102 non-null    float64
#  5   hdlngth   104 non-null    float64
#  6   skullw    104 non-null    float64
#  7   totlngth  104 non-null    float64
#  8   taill     104 non-null    float64
#  9   footlgth  103 non-null    float64
#  10  earconch  104 non-null    float64
#  11  eye       104 non-null    float64
#  12  chest     104 non-null    float64
#  13  belly     104 non-null    float64
# dtypes: float64(10), int64(2), object(2)
# memory usage: 11.5+ KB

# %%
df.describe()
# Out:
#              case        site         age     hdlngth      skullw    totlngth  \
# count  104.000000  104.000000  102.000000  104.000000  104.000000  104.000000
# mean    52.500000    3.625000    3.833333   92.602885   56.883654   87.088462
# std     30.166206    2.349086    1.909244    3.573349    3.113426    4.310549
# min      1.000000    1.000000    1.000000   82.500000   50.000000   75.000000
# 25%     26.750000    1.000000    2.250000   90.675000   54.975000   84.000000
# 50%     52.500000    3.000000    3.000000   92.800000   56.350000   88.000000
# 75%     78.250000    6.000000    5.000000   94.725000   58.100000   90.000000
# max    104.000000    7.000000    9.000000  103.100000   68.600000   96.500000
#
#             taill    footlgth    earconch         eye       chest       belly
# count  104.000000  103.000000  104.000000  104.000000  104.000000  104.000000
# mean    37.009615   68.459223   48.130769   15.046154   27.000000   32.586538
# std      1.959518    4.395306    4.109380    1.050374    2.045597    2.761949
# min     32.000000   60.300000   40.300000   12.800000   22.000000   25.000000
# 25%     35.875000   64.600000   44.800000   14.400000   25.500000   31.000000
# 50%     37.000000   68.000000   46.800000   14.900000   27.000000   32.500000
# 75%     38.000000   72.500000   52.000000   15.725000   28.000000   34.125000
# max     43.000000   77.900000   56.200000   17.800000   32.000000   40.000000

# %%
df.isnull().mean()*100
# Out:
# case        0.000000
# site        0.000000
# Pop         0.000000
# sex         0.000000
# age         1.923077
# hdlngth     0.000000
# skullw      0.000000
# totlngth    0.000000
# taill       0.000000
# footlgth    0.961538
# earconch    0.000000
# eye         0.000000
# chest       0.000000
# belly       0.000000
# dtype: float64

# %% [markdown]
# ### Replacing null values with mean

# %%
df.age.fillna(df.age.mean(), inplace=True)

# %%
df.footlgth.fillna(df.footlgth.mean(),inplace=True)

# %%
df.isnull().mean()*100
# Out:
# case        0.0
# site        0.0
# Pop         0.0
# sex         0.0
# age         0.0
# hdlngth     0.0
# skullw      0.0
# totlngth    0.0
# taill       0.0
# footlgth    0.0
# earconch    0.0
# eye         0.0
# chest       0.0
# belly       0.0
# dtype: float64

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Univariate Analysis:

# %%
for i in df.columns:
    if df[i].dtype !="object":
        sns.histplot(x=df[i])
        plt.show()

# %%
for i in df.columns:
    if df[i].dtype !="object":
        sns.kdeplot(x=df[i])
        plt.show()

# %%
for i in df.columns:
    if df[i].dtype!="object":
        sns.boxplot(y=df[i],color='red')
        plt.show()

# %%
def outlier_limit(col):
    Q3,Q1=np.nanpercentile(col,[75,25])
    IQR=Q3-Q1
    UL=Q3+1.5*IQR
    LL=Q1-1.5*IQR
    return UL,LL

# %%
for i in df.columns:
    if df[i].dtype !="object":
        UL,LL = outlier_limit(df[i])
        df[i] = np.where((df[i]>UL)|(df[i]<LL), np.nan, df[i])

# %%
for i in df.columns:
    if df[i].dtype != "object":
        sns.boxplot(y=df[i],color='green')
        plt.show();

# %%
df.dropna(inplace=True)
df
# Out:
#       case  site    Pop sex  age  hdlngth  skullw  totlngth  taill  footlgth  \
# 0      1.0   1.0    Vic   m  8.0     94.1    60.4      89.0   36.0      74.5
# 1      2.0   1.0    Vic   f  6.0     92.5    57.6      91.5   36.5      72.5
# 2      3.0   1.0    Vic   f  6.0     94.0    60.0      95.5   39.0      75.4
# 3      4.0   1.0    Vic   f  6.0     93.2    57.1      92.0   38.0      76.1
# 4      5.0   1.0    Vic   f  2.0     91.5    56.3      85.5   36.0      71.0
# ..     ...   ...    ...  ..  ...      ...     ...       ...    ...       ...
# 99   100.0   7.0  other   m  1.0     89.5    56.0      81.5   36.5      66.0
# 100  101.0   7.0  other   m  1.0     88.6    54.7      82.5   39.0      64.4
# 101  102.0   7.0  other   f  6.0     92.4    55.0      89.0   38.0      63.5
# 102  103.0   7.0  other   m  4.0     91.5    55.2      82.5   36.5      62.9
# 103  104.0   7.0  other   f  3.0     93.6    59.9      89.0   40.0      67.6
#
#      earconch   eye  chest  belly
# 0        54.5  15.2   28.0   36.0
# 1        51.2  16.0   28.5   33.0
# 2        51.9  15.5   30.0   34.0
# 3        52.2  15.2   28.0   34.0
# 4        53.2  15.1   28.5   33.0
# ..        ...   ...    ...    ...
# 99       46.8  14.8   23.0   27.0
# 100      48.0  14.0   25.0   33.0
# 101      45.4  13.0   25.0   30.0
# 102      45.9  15.4   25.0   29.0
# 103      46.0  14.8   28.5   33.5
#
# [86 rows x 14 columns]

# %%
le = LabelEncoder()

# %%
df['Pop']=le.fit_transform(df['Pop'])

# %%
df['sex']=le.fit_transform(df['sex'])

# %%
sns.heatmap(df.corr()[["footlgth"]].sort_values(by="footlgth", ascending=False), vmax=1, vmin=-1, annot=True, cmap="autumn")
# Out:
# <AxesSubplot: >

# %%
k.corr_plot(data=df,target='footlgth');

# %% [markdown]
# # selecting features  X

# %%
x= df[['hdlngth','earconch','totlngth','chest','belly','skullw']].values

# %% [markdown]
# # selecting target column

# %%
y=df[['footlgth']].values

# %% [markdown]
# # FEATURE SCALING

# %%
sc= StandardScaler()
x=sc.fit_transform(x)

# %%
x_train, x_test, y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=0)

# %% [markdown]
# # model building

# %%
models ={
    "LinearRegression" : LinearRegression(),
    "Ridge":Ridge(),
    "LinearSVR":LinearSVR(),
    "Lasso":Lasso(),
    "GradientBoostingRegressor":GradientBoostingRegressor(),
    "BaggingRegressor":BaggingRegressor(),
    "ExtraTreesRegressor":ExtraTreesRegressor(),
    "HistGradientBoostingRegressor":HistGradientBoostingRegressor(),
    "DecisionTreeRegressor":DecisionTreeRegressor(),
    "AdaBoostRegressor":AdaBoostRegressor(),
    "RandomForestRegressor":RandomForestRegressor(random_state=0),
}

# %%
for name,model in models.items():
    model.fit(x_train,y_train)
    print("model trained with {}".format(name))
    training_score = model.score(x_train,y_train)*100
    testing_score = model.score(x_test,y_test)*100
    score = r2_score(y_test,model.predict(x_test))*100
    mae= mean_absolute_error(y_test,model.predict(x_test))
    mse = mean_squared_error(y_test,model.predict(x_test)) 
    rmse = np.sqrt(mse)
    print("r2_score: ",score)
    print("training score: ",training_score)
    print("testing_score:  ",testing_score)
    print("mae: ",mae)
    print("mse: ",mse)
    print("rmse_test: ",rmse)
    print("*"*100)
# Out:
# model trained with LinearRegression
# r2_score:  66.22854497178831
# training score:  76.9716402229538
# testing_score:   66.22854497178831
# mae:  1.6483887419654135
# mse:  4.459134974797564
# rmse_test:  2.111666397610561
# ****************************************************************************************************
# model trained with Ridge
# r2_score:  66.719491157808
# training score:  76.95211903875068
# testing_score:   66.719491157808
# mae:  1.62509988554073
# mse:  4.394311137417887
# rmse_test:  2.096261228334362
# ****************************************************************************************************
# model trained with LinearSVR
# r2_score:  -323.266618932736
# training score:  -132.0298560079231
# testing_score:   -323.266618932736
# mae:  6.789029532028099
# mse:  55.887523429789866
# rmse_test:  7.475795839226073
# ****************************************************************************************************
# model trained with Lasso
# r2_score:  59.87567710876826
# training score:  66.3913922192766
# testing_score:   59.87567710876826
# mae:  1.8670324504373907
# mse:  5.297958627926976
# rmse_test:  2.3017294862617925
# ****************************************************************************************************
# model trained with GradientBoostingRegressor
# r2_score:  54.644167852297024
# training score:  99.75622141239694
# testing_score:   54.644167852297024
# mae:  1.9009120071275527
# mse:  5.988719682700025
# rmse_test:  2.4471860743923877
# ****************************************************************************************************
# model trained with BaggingRegressor
# r2_score:  64.8957660213634
# training score:  95.00741243861994
# testing_score:   64.8957660213634
# mae:  1.6790938511326838
# mse:  4.63511321519464
# rmse_test:  2.1529313075884797
# ****************************************************************************************************
# model trained with ExtraTreesRegressor
# r2_score:  69.48569849503804
# training score:  100.0
# testing_score:   69.48569849503804
# mae:  1.569876483279382
# mse:  4.029065047941437
# rmse_test:  2.007253110083887
# ****************************************************************************************************
# model trained with HistGradientBoostingRegressor
# r2_score:  73.04301096127202
# training score:  90.11589011264938
# testing_score:   73.04301096127202
# mae:  1.4845240955831243
# mse:  3.5593625604052557
# rmse_test:  1.886627297694289
# ****************************************************************************************************
# model trained with DecisionTreeRegressor
# r2_score:  63.22623625249824
# training score:  100.0
# testing_score:   63.22623625249824
# mae:  1.8111111111111104
# mse:  4.855555555555554
# rmse_test:  2.2035325174717877
# ****************************************************************************************************
# model trained with AdaBoostRegressor
# r2_score:  60.58039697355559
# training score:  94.55603896709079
# testing_score:   60.58039697355559
# mae:  1.8060438432249006
# mse:  5.204908417508659
# rmse_test:  2.2814268380793323
# ****************************************************************************************************
# model trained with RandomForestRegressor
# r2_score:  62.41313773894195
# training score:  96.88116889539567
# testing_score:   62.41313773894195
# mae:  1.7826440129449814
# mse:  4.962915928886403
# rmse_test:  2.2277602943060106
# ****************************************************************************************************
